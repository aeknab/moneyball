# %%
import pandas as pd
from openai import OpenAI

# Set OpenAI API key
client = OpenAI(api_key="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")

# Function to send chat to the OpenAI API
def send_chat_to_api(text):
    model_engine = "gpt-3.5-turbo"
    messages = [
        {"role": "system", "content": "You are a media reputation analyst without own opinions, be sober, factual and brief."},
        {"role": "user", "content": text},
    ]

    # API call
    response = client.chat.completions.create(
        model=model_engine,
        messages=messages,
        temperature=0
    )
    reply_text = response.choices[0].message.content

    return reply_text

# Send call to the API and get the response
reply_text = send_chat_to_api("what is 3+4")
print(reply_text)

###

# Import necessary modules
from openai import OpenAI
import openai
import os
import pandas as pd

# Path to Table
file_path = "/Users/Andreas/Desktop/Spiced Academy/GitHub/lemongrass-regression-student-code/week_11_12_final_project/data/Tipps/tipps1.csv"

# Prompt file path
prompt_file_path = "/Users/Andreas/Downloads/tomitest.txt"

# Set OpenAI API key
client = OpenAI(api_key = "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")

# Function to send chat to the OpenAI API
def send_chat_to_api(text):
    model_engine = "gpt-3.5-turbo"
    messages = [{"role": "system", "content": "You are a media reputation analyst without own opinions, be sober, factual and brief."},
                {"role": "user", "content": text}]
   
    try:
        response = client.chat.completions.create(
            model=model_engine,
            messages=messages,
            temperature=1
        )
        # Assuming 'response' is a dictionary and the structure matches the API documentation
        reply_text = response.choices[0].message.content
        return reply_text
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# Load the sheet into a DataFrame
try:
    df = pd.read_csv(file_path)
    # Convert the DataFrame to a string
#     df_string = df.to_string()
except Exception as e:
    print(f"An error occurred: {e}")
    exit()

# Read the prompt text
try:
    with open(prompt_file_path, 'r', encoding='utf-8') as file:
        prompt_text_template = file.read()
except Exception as e:
    print(f"An error occurred while reading the prompt file: {e}")
    exit()

# Combine the texts
combined_text = prompt_text_template + df.to_string()

# Send the combined text to the API and get the response
reply_text = send_chat_to_api(combined_text)

# Print the API response
print(reply_text)
# Out:
# 3 + 4 equals 7.
# An error occurred: [Errno 2] No such file or directory: '/Users/Andreas/Desktop/Spiced Academy/GitHub/lemongrass-regression-student-code/week_11_12_final_project/data/Tipps/tipps1.csv'
# An error occurred while reading the prompt file: [Errno 2] No such file or directory: '/Users/Andreas/Downloads/tomitest.txt'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[152], line 83
#      80     exit()
#      82 # Combine the texts
# ---> 83 combined_text = prompt_text_template + df.to_string()
#      85 # Send the combined text to the API and get the response
#      86 reply_text = send_chat_to_api(combined_text)
#
# NameError: name 'prompt_text_template' is not defined
